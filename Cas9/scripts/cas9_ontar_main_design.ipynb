# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Cas9/On target')
# Out:
# Mounted at /content/drive

# %%
import requests
import tensorflow as tf
import pandas as pd
import numpy as np
from operator import add
from functools import reduce
import random
import tabulate

from keras import Model
from keras import regularizers
from keras.optimizers import Adam
from keras.layers import Conv2D, BatchNormalization, ReLU, Input, Flatten, Softmax
from keras.layers import Concatenate, Activation, Dense, GlobalAveragePooling2D, Dropout
from keras.layers import AveragePooling1D, Bidirectional, LSTM, GlobalAveragePooling1D, MaxPool1D, Reshape
from keras.layers import LayerNormalization, Conv1D, MultiHeadAttention, Layer
from keras.models import load_model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# !pip install cyvcf2
import cyvcf2
# !pip install parasail
import parasail

import re
# Out:
# Collecting cyvcf2
#   Downloading cyvcf2-0.30.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from cyvcf2) (1.25.2)
# Collecting coloredlogs (from cyvcf2)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from cyvcf2) (8.1.7)
# Collecting humanfriendly>=9.1 (from coloredlogs->cyvcf2)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, cyvcf2
# Successfully installed coloredlogs-15.0.1 cyvcf2-0.30.28 humanfriendly-10.0
# Collecting parasail
#   Downloading parasail-1.3.4-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 55.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from parasail) (1.25.2)
# Installing collected packages: parasail
# Successfully installed parasail-1.3.4

# %% [markdown]
# ### Data Encoding

# %%
ntmap = {'A': (1, 0, 0, 0),
         'C': (0, 1, 0, 0),
         'G': (0, 0, 1, 0),
         'T': (0, 0, 0, 1)
         }

def get_seqcode(seq):
    return np.array(reduce(add, map(lambda c: ntmap[c], seq.upper()))).reshape((1, len(seq), -1))

# %% [markdown]
# ### Attention model

# %%
class PositionalEncoding(Layer):
    def __init__(self, sequence_len=None, embedding_dim=None,**kwargs):
        super(PositionalEncoding, self).__init__()
        self.sequence_len = sequence_len
        self.embedding_dim = embedding_dim

    def call(self, x):

        position_embedding = np.array([
            [pos / np.power(10000, 2. * i / self.embedding_dim) for i in range(self.embedding_dim)]
            for pos in range(self.sequence_len)])

        position_embedding[:, 0::2] = np.sin(position_embedding[:, 0::2])  # dim 2i
        position_embedding[:, 1::2] = np.cos(position_embedding[:, 1::2])  # dim 2i+1
        position_embedding = tf.cast(position_embedding, dtype=tf.float32)

        return position_embedding+x

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'sequence_len' : self.sequence_len,
            'embedding_dim' : self.embedding_dim,
        })
        return config

def MultiHeadAttention_model(input_shape):
    input = Input(shape=input_shape)

    conv1 = Conv1D(256, 3, activation="relu")(input)
    pool1 = AveragePooling1D(2)(conv1)
    drop1 = Dropout(0.4)(pool1)

    conv2 = Conv1D(256, 3, activation="relu")(drop1)
    pool2 = AveragePooling1D(2)(conv2)
    drop2 = Dropout(0.4)(pool2)

    lstm = Bidirectional(LSTM(128,
                               dropout=0.5,
                               activation='tanh',
                               return_sequences=True,
                               kernel_regularizer=regularizers.l2(0.01)))(drop2)

    pos_embedding = PositionalEncoding(sequence_len=int(((23-3+1)/2-3+1)/2), embedding_dim=2*128)(lstm)
    atten = MultiHeadAttention(num_heads=2,
                               key_dim=64,
                               dropout=0.2,
                               kernel_regularizer=regularizers.l2(0.01))(pos_embedding, pos_embedding)

    flat = Flatten()(atten)

    dense1 = Dense(512,
                   kernel_regularizer=regularizers.l2(1e-4),
                   bias_regularizer=regularizers.l2(1e-4),
                   activation="relu")(flat)
    drop3 = Dropout(0.1)(dense1)

    dense2 = Dense(128,
                   kernel_regularizer=regularizers.l2(1e-4),
                   bias_regularizer=regularizers.l2(1e-4),
                   activation="relu")(drop3)
    drop4 = Dropout(0.1)(dense2)

    dense3 = Dense(256,
                   kernel_regularizer=regularizers.l2(1e-4),
                   bias_regularizer=regularizers.l2(1e-4),
                   activation="relu")(drop4)
    drop5 = Dropout(0.1)(dense3)

    output = Dense(1, activation="linear")(drop5)

    model = Model(inputs=[input], outputs=[output])
    return model

# %% [markdown]
# ### Predict gRNA in one specific gene

# %%
def fetch_ensembl_transcripts(gene_symbol):
    url = f"https://rest.ensembl.org/lookup/symbol/homo_sapiens/{gene_symbol}?expand=1;content-type=application/json"
    response = requests.get(url)
    if response.status_code == 200:
        gene_data = response.json()
        if 'Transcript' in gene_data:
            return gene_data['Transcript']
        else:
            print("No transcripts found for gene:", gene_symbol)
            return None
    else:
        print(f"Error fetching gene data from Ensembl: {response.text}")
        return None

def fetch_ensembl_sequence(transcript_id):
    url = f"https://rest.ensembl.org/sequence/id/{transcript_id}?content-type=application/json"
    response = requests.get(url)
    if response.status_code == 200:
        sequence_data = response.json()
        if 'seq' in sequence_data:
            return sequence_data['seq']
        else:
            print("No sequence found for transcript:", transcript_id)
            return None
    else:
        print(f"Error fetching sequence data from Ensembl: {response.text}")
        return None

# %%
def find_crispr_targets(sequence, chr, start, end, strand, transcript_id, exon_id, pam="NGG", target_length=20):
    targets = []
    len_sequence = len(sequence)
    #complement = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}
    dnatorna = {'A': 'A', 'T': 'U', 'C': 'C', 'G': 'G'}

    for i in range(len_sequence - len(pam) + 1):
        if sequence[i + 1:i + 3] == pam[1:]:
            if i >= target_length:
                target_seq = sequence[i - target_length:i + 3]
                if strand == -1:
                    tar_start = end - (i + 2)
                    tar_end = end - (i - target_length)
                    #seq_in_ref = ''.join([complement[base] for base in target_seq])[::-1]
                else:
                    tar_start = start + i - target_length
                    tar_end = start + i + 3 - 1
                    #seq_in_ref = target_seq
                gRNA = ''.join([dnatorna[base] for base in sequence[i - target_length:i]])
                #targets.append([target_seq, gRNA, chr, str(tar_start), str(tar_end), str(strand), transcript_id, exon_id, seq_in_ref])
                targets.append([target_seq, gRNA, chr, str(tar_start), str(tar_end), str(strand), transcript_id, exon_id])

    return targets

# %%
# Function to predict on-target efficiency and format output
def format_prediction_output(targets, model_path):
    model = MultiHeadAttention_model(input_shape=(23, 4))
    model.load_weights(model_path)

    formatted_data = []

    for target in targets:
        # Encode the gRNA sequence
        encoded_seq = get_seqcode(target[0])

        # Predict on-target efficiency using the model
        prediction = float(list(model.predict(encoded_seq, verbose=0)[0])[0])
        if prediction > 100:
            prediction = 100

        # Format output
        gRNA = target[1]
        chr = target[2]
        start = target[3]
        end = target[4]
        strand = target[5]
        transcript_id = target[6]
        exon_id = target[7]
        #seq_in_ref = target[8]
        #formatted_data.append([chr, start, end, strand, transcript_id, exon_id, target[0], gRNA, seq_in_ref, prediction[0]])
        formatted_data.append([chr, start, end, strand, transcript_id, exon_id, target[0], gRNA, prediction])

    return formatted_data

# %%
def gRNADesign(gene_symbol, model_path, write_to_csv=False):
    transcripts = fetch_ensembl_transcripts(gene_symbol)
    results = []
    if transcripts:
        for i in range(len(transcripts)):
            Exons = transcripts[i]['Exon']
            transcript_id = transcripts[i]['id']
            for j in range(len(Exons)):
                exon_id = Exons[j]['id']
                gene_sequence = fetch_ensembl_sequence(exon_id)
                if gene_sequence:
                    start = Exons[j]['start']
                    end = Exons[j]['end']
                    strand = Exons[j]['strand']
                    chr = Exons[j]['seq_region_name']
                    targets = find_crispr_targets(gene_sequence, chr, start, end, strand, transcript_id, exon_id)
                    if targets:
                        formatted_data = format_prediction_output(targets, model_path)
                        results.append(formatted_data)

    #header = ['Chr','Start','End','Strand','Transcript','Exon','Target sequence (5\' to 3\')','gRNA','Sequence in reference genome','pred_Score']
    header = ['Chrom','Start','End','Strand','Transcript','Exon','Target sequence (5\' to 3\')','gRNA','pred_Score']
    output = []
    for result in results:
        for item in result:
            output.append(item)
    sort_output = sorted(output, key=lambda x: x[8], reverse=True)

    if write_to_csv==True:
        pd.DataFrame(data=sort_output, columns=header).to_csv(f'/content/drive/MyDrive/Colab Notebooks/Cas9/On target/design_results/Cas9_{gene_symbol}.csv')
    else:
        return sort_output

# %%
# design
genes = ['TROAP','SPC24','RAD54L','MCM2','COPB2','CKAP5']
model_path = '/content/drive/MyDrive/Colab Notebooks/Cas9/On target/saved_model/Cas9_MultiHeadAttention_weights.keras'

for gene in genes:
    gRNADesign(gene, model_path, write_to_csv=True)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78d440f11120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78d4443c3880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ### Combine with VCF information

# %% [markdown]
# ##### Benchmarking with labelled MDA-MB-231 mutations

# %%
# read VCF file
vcf_reader = cyvcf2.VCF('/content/drive/MyDrive/Colab Notebooks/CRISPR_data/SRR25934512.filter.snps.indels.vcf.gz')

# %%
# read background mutations in MDAMB321 from Depmap
mdamb321_mut_bg = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CRISPR_data/MDAMB231 mutations.csv')
mdamb321_mut_bg
# Out:
#        Gene Chromosome   Position Variant Type  \
# 0      CHD5       chr1    6131677     deletion
# 1    EIF4G3       chr1   20969478          SNV
# 2     ODF2L       chr1   86382979          SNV
# 3     GTF2B       chr1   88860139          SNV
# 4     LRIG2       chr1  113112563          SNV
# ..      ...        ...        ...          ...
# 271  ADGRG2       chrX   19028184          SNV
# 272  MAGEB3       chrX   30236624          SNV
# 273   NR0B1       chrX   30308885          SNV
# 274  CFAP47       chrX   36046943          SNV
# 275    TERT       chr5    1295113          SNV
#
#                                Variant Info Ref Allele Alt Allele  \
# 0                        frameshift_variant         AC          A
# 1                          missense_variant          G          A
# 2                          missense_variant          T          G
# 3                      splice_donor_variant          C          A
# 4                          missense_variant          A          G
# ..                                      ...        ...        ...
# 271  missense_variant&splice_region_variant          T          G
# 272                        missense_variant          G          A
# 273                        missense_variant          G          T
# 274                        missense_variant          G          T
# 275                   upstream_gene_variant          G          A
#
#      Allele Fraction  Ref Count  Alt Count  ... Vep Mane Select  \
# 0              0.400         21         13  ...     NM_015557.3
# 1              0.678          9         21  ...  NM_001391906.1
# 2              0.656         10         21  ...  NM_001366781.1
# 3              0.421         21         15  ...     NM_001514.6
# 4              0.714         13         35  ...     NM_014813.3
# ..               ...        ...        ...  ...             ...
# 271            0.233         24          6  ...  NM_001079858.3
# 272            0.315         12          5  ...     NM_002365.5
# 273            0.767          6         23  ...     NM_000475.5
# 274            0.414         16         12  ...  NM_001304548.2
# 275            0.399         12          8  ...     NM_198253.3
#
#                                  Sift         Vep Ensp  Ensembl Gene Id  \
# 0                                 NaN  ENSP00000262450  ENSG00000116254
# 1       deleterious_low_confidence(0)  ENSP00000473510  ENSG00000075151
# 2                      deleterious(0)  ENSP00000433092  ENSG00000122417
# 3                                 NaN  ENSP00000359531  ENSG00000137947
# 4    deleterious_low_confidence(0.01)  ENSP00000355396  ENSG00000198799
# ..                                ...              ...              ...
# 271    tolerated_low_confidence(0.28)  ENSP00000369198  ENSG00000173698
# 272                   tolerated(0.25)  ENSP00000355198  ENSG00000198798
# 273    tolerated_low_confidence(0.05)  ENSP00000368253  ENSG00000169297
# 274                   tolerated(0.15)  ENSP00000367922  ENSG00000165164
# 275                               NaN  ENSP00000309572  ENSG00000164362
#
#     Provean Prediction  Nmd Vep Somatic  Lof Number Of Transcripts In Gene  \
# 0                  NaN  NaN         NaN                                1.0
# 1             Damaging  NaN         NaN                                NaN
# 2             Damaging  NaN         NaN                                NaN
# 3                  NaN  NaN         NaN                                1.0
# 4             Damaging  NaN           1                                NaN
# ..                 ...  ...         ...                                ...
# 271            Neutral  NaN         NaN                                NaN
# 272            Neutral  NaN           1                                NaN
# 273            Neutral  NaN         1&1                                NaN
# 274                NaN  NaN         NaN                                NaN
# 275                NaN  NaN         NaN                                NaN
#
#      Vep Impact  Oncogene High Impact
# 0          HIGH                 False
# 1      MODERATE                 False
# 2      MODERATE                 False
# 3          HIGH                 False
# 4      MODERATE                 False
# ..          ...                   ...
# 271    MODERATE                 False
# 272    MODERATE                 False
# 273    MODERATE                 False
# 274    MODERATE                 False
# 275    MODIFIER                 False
#
# [276 rows x 63 columns]

# %%
# intersect
mutation_pos = []
for mutation in vcf_reader:
    mutation_pos.append(mutation.POS)

mdamb321_mut_remain_idx = []
for i in range(len(mdamb321_mut_bg)):
    if mdamb321_mut_bg['Position'][i] in mutation_pos:
        mdamb321_mut_remain_idx.append(i)

mdamb321_mut_remain = mdamb321_mut_bg.iloc[mdamb321_mut_remain_idx,:]
mdamb321_mut_remain
# Out:
#        Gene Chromosome   Position Variant Type      Variant Info Ref Allele  \
# 2     ODF2L       chr1   86382979          SNV  missense_variant          T
# 4     LRIG2       chr1  113112563          SNV  missense_variant          A
# 9      RGS5       chr1  163147354          SNV  missense_variant          C
# 10      TPR       chr1  186327474          SNV  missense_variant          C
# 11     ASPM       chr1  197104987          SNV  missense_variant          A
# ..      ...        ...        ...          ...               ...        ...
# 265   ZBTB6       chr9  122911153          SNV  missense_variant          G
# 266   REXO4       chr9  133417769          SNV  missense_variant          G
# 267  SEC16A       chr9  136476666          SNV  missense_variant          A
# 268  MT-ND4       chrM      12084          SNV  missense_variant          C
# 269  MT-ND5       chrM      13966          SNV  missense_variant          A
#
#     Alt Allele  Allele Fraction  Ref Count  Alt Count  ... Vep Mane Select  \
# 2            G            0.656         10         21  ...  NM_001366781.1
# 4            G            0.714         13         35  ...     NM_014813.3
# 9            A            0.228         20          5  ...     NM_003617.4
# 10           A            0.263         14          4  ...     NM_003292.3
# 11           G            0.427         26         19  ...     NM_018136.5
# ..         ...              ...        ...        ...  ...             ...
# 265          A            0.447         19         15  ...     NM_006626.6
# 266          C            0.382         25         15  ...     NM_020385.4
# 267          C            0.418         27         17  ...     NM_014866.2
# 268          T            1.000          2       4818  ...             NaN
# 269          G            1.000          1       4704  ...             NaN
#
#                                  Sift         Vep Ensp  Ensembl Gene Id  \
# 2                      deleterious(0)  ENSP00000433092  ENSG00000122417
# 4    deleterious_low_confidence(0.01)  ENSP00000355396  ENSG00000198799
# 9                        tolerated(1)  ENSP00000319308  ENSG00000143248
# 10                  deleterious(0.04)  ENSP00000356448  ENSG00000047410
# 11                     deleterious(0)  ENSP00000356379  ENSG00000066279
# ..                                ...              ...              ...
# 265                 deleterious(0.02)  ENSP00000362763  ENSG00000186130
# 266                    tolerated(0.3)  ENSP00000361010  ENSG00000148300
# 267                   tolerated(0.08)  ENSP00000508822  ENSG00000148396
# 268    tolerated_low_confidence(0.23)  ENSP00000354961  ENSG00000198886
# 269    tolerated_low_confidence(0.21)  ENSP00000354813  ENSG00000198786
#
#     Provean Prediction  Nmd Vep Somatic  Lof Number Of Transcripts In Gene  \
# 2             Damaging  NaN         NaN                                NaN
# 4             Damaging  NaN           1                                NaN
# 9              Neutral  NaN         NaN                                NaN
# 10             Neutral  NaN         NaN                                NaN
# 11            Damaging  NaN           1                                NaN
# ..                 ...  ...         ...                                ...
# 265           Damaging  NaN           1                                NaN
# 266            Neutral  NaN         NaN                                NaN
# 267            Neutral  NaN         NaN                                NaN
# 268                NaN  NaN         NaN                                NaN
# 269                NaN  NaN         NaN                                NaN
#
#      Vep Impact  Oncogene High Impact
# 2      MODERATE                 False
# 4      MODERATE                 False
# 9      MODERATE                 False
# 10     MODERATE                 False
# 11     MODERATE                 False
# ..          ...                   ...
# 265    MODERATE                 False
# 266    MODERATE                 False
# 267    MODERATE                 False
# 268    MODERATE                 False
# 269    MODERATE                 False
#
# [124 rows x 63 columns]

# %% [markdown]
# ##### Predict cell type-specific gRNA

# %%
def fetch_ensembl_transcripts(gene_symbol):
    url = f"https://rest.ensembl.org/lookup/symbol/homo_sapiens/{gene_symbol}?expand=1;content-type=application/json"
    response = requests.get(url)
    if response.status_code == 200:
        gene_data = response.json()
        if 'Transcript' in gene_data:
            return gene_data['Transcript']
        else:
            print("No transcripts found for gene:", gene_symbol)
            return None
    else:
        print(f"Error fetching gene data from Ensembl: {response.text}")
        return None

def fetch_ensembl_sequence(transcript_id):
    url = f"https://rest.ensembl.org/sequence/id/{transcript_id}?content-type=application/json"
    response = requests.get(url)
    if response.status_code == 200:
        sequence_data = response.json()
        if 'seq' in sequence_data:
            return sequence_data['seq']
        else:
            print("No sequence found for transcript:", transcript_id)
            return None
    else:
        print(f"Error fetching sequence data from Ensembl: {response.text}")
        return None

# %%
def apply_mutation(ref_sequence, offset, ref, alt):
    """
    Apply a single mutation to the sequence.
    """
    if len(ref) == len(alt) and alt != "*":  # SNV
        mutated_seq = ref_sequence[:offset] + alt + ref_sequence[offset+len(alt):]

    elif len(ref) < len(alt):  # Insertion
        mutated_seq = ref_sequence[:offset] + alt + ref_sequence[offset+1:]

    elif len(ref) == len(alt) and alt == "*":  # Deletion
        mutated_seq = ref_sequence[:offset] + ref_sequence[offset+1:]

    elif len(ref) > len(alt) and alt != "*":  # Deletion
        mutated_seq = ref_sequence[:offset] + alt + ref_sequence[offset+len(ref):]

    elif len(ref) > len(alt) and alt == "*":  # Deletion
        mutated_seq = ref_sequence[:offset] + ref_sequence[offset+len(ref):]

    return mutated_seq

# %%
def construct_combinations(sequence, mutations):
    """
    Construct all combinations of mutations.
    mutations is a list of tuples (position, ref, [alts])
    """
    if not mutations:
        return [sequence]

    # Take the first mutation and recursively construct combinations for the rest
    first_mutation = mutations[0]
    rest_mutations = mutations[1:]
    offset, ref, alts = first_mutation

    sequences = []
    for alt in alts:
        mutated_sequence = apply_mutation(sequence, offset, ref, alt)
        sequences.extend(construct_combinations(mutated_sequence, rest_mutations))

    return sequences

# %%
def needleman_wunsch_alignment(query_seq, ref_seq):
    """
    Use Needleman-Wunsch alignment to find the maximum alignment position in ref_seq
    Use this position to represent the position of target sequence with mutations
    """
    # Needleman-Wunsch alignment
    alignment = parasail.nw_trace(query_seq, ref_seq, 10, 1, parasail.blosum62)

    # extract CIGAR object
    cigar = alignment.cigar
    cigar_string = cigar.decode.decode("utf-8")

    # record ref_pos
    ref_pos = 0

    matches = re.findall(r'(\d+)([MIDNSHP=X])', cigar_string)
    max_num_before_equal = 0
    max_equal_index = -1
    total_before_max_equal = 0

    for i, (num_str, op) in enumerate(matches):
        num = int(num_str)
        if op == '=':
            if num > max_num_before_equal:
                max_num_before_equal = num
                max_equal_index = i
    total_before_max_equal = sum(int(matches[j][0]) for j in range(max_equal_index))

    ref_pos = total_before_max_equal

    return ref_pos

# %%
def find_gRNA_with_mutation(ref_sequence, exon_chr, start, end, strand, transcript_id,
                            exon_id, gene_symbol, vcf_reader, pam="NGG", target_length=20):
    # initialization
    mutated_sequences = [ref_sequence]

    # find mutations within interested region
    mutations = vcf_reader(f"{exon_chr}:{start}-{end}")
    if mutations:
        # find mutations
        mutation_list = []
        for mutation in mutations:
            offset = mutation.POS - start
            ref = mutation.REF
            alts = mutation.ALT[:-1]
            mutation_list.append((offset, ref, alts))

        # replace reference sequence of mutation
        mutated_sequences = construct_combinations(ref_sequence, mutation_list)

    # find gRNA in ref_sequence or all mutated_sequences
    targets = []
    for seq in mutated_sequences:
        len_sequence = len(seq)
        dnatorna = {'A': 'A', 'T': 'U', 'C': 'C', 'G': 'G'}
        for i in range(len_sequence - len(pam) + 1):
            if seq[i + 1:i + 3] == pam[1:]:
                if i >= target_length:
                    target_seq = seq[i - target_length:i + 3]
                    pos = ref_sequence.find(target_seq)
                    if pos != -1:
                        is_mut = False
                        if strand == -1:
                            tar_start = end - pos - target_length - 2
                        else:
                            tar_start = start + pos
                    else:
                        is_mut = True
                        nw_pos = needleman_wunsch_alignment(target_seq, ref_sequence)
                        if strand == -1:
                            tar_start = str(end - nw_pos - target_length - 2) + '*'
                        else:
                            tar_start = str(start + nw_pos) + '*'
                    gRNA = ''.join([dnatorna[base] for base in seq[i - target_length:i]])
                    targets.append([target_seq, gRNA, exon_chr, str(strand), str(tar_start), transcript_id, exon_id, gene_symbol, is_mut])

    # filter duplicated targets
    unique_targets_set = set(tuple(element) for element in targets)
    unique_targets = [list(element) for element in unique_targets_set]

    return unique_targets

# %%
def format_prediction_output_with_mutation(targets, model_path):
    model = MultiHeadAttention_model(input_shape=(23, 4))
    model.load_weights(model_path)

    formatted_data = []

    for target in targets:
        # Encode the gRNA sequence
        encoded_seq = get_seqcode(target[0])


        # Predict on-target efficiency using the model
        prediction = float(list(model.predict(encoded_seq, verbose=0)[0])[0])
        if prediction > 100:
            prediction = 100

        # Format output
        gRNA = target[1]
        exon_chr = target[2]
        strand = target[3]
        tar_start = target[4]
        transcript_id = target[5]
        exon_id = target[6]
        gene_symbol = target[7]
        is_mut = target[8]
        formatted_data.append([gene_symbol, exon_chr, strand, tar_start, transcript_id,
                               exon_id, target[0], gRNA, prediction, is_mut])

    return formatted_data

# %%
def gRNADesign_mutation(gene_symbol, vcf_reader, model_path, write_to_csv=False):
    results = []

    transcripts = fetch_ensembl_transcripts(gene_symbol)
    if transcripts:
        for transcript in transcripts:
            Exons = transcript['Exon']
            transcript_id = transcript['id']

            for Exon in Exons:
                exon_id = Exon['id']
                exon_chr = Exon['seq_region_name']
                start = Exon['start']
                end = Exon['end']
                strand = Exon['strand']
                gene_sequence = fetch_ensembl_sequence(exon_id) # reference exon sequence

                if gene_sequence:
                    targets = find_gRNA_with_mutation(gene_sequence, exon_chr, start, end, strand,
                                                      transcript_id, exon_id, gene_symbol, vcf_reader)
                    if targets:
                        # Predict on-target efficiency for each gRNA site
                        formatted_data = format_prediction_output_with_mutation(targets, model_path)
                        results.append(formatted_data)
    header = ['Gene','Chrom','Strand','Start','Transcript','Exon','Target sequence (5\' to 3\')','gRNA','pred_Score','Is_mutation']
    output = []
    for result in results:
        for item in result:
            output.append(item)
    sort_output = sorted(output, key=lambda x: x[8], reverse=True)

    if write_to_csv==True:
        pd.DataFrame(data=sort_output, columns=header).to_csv(f'/content/drive/MyDrive/Colab Notebooks/Cas9/On target/design_results/Cas9_{gene_symbol}_mut.csv')
    else:
        return sort_output

# %%
# design
genes = ['TROAP','SPC24','RAD54L','MCM2','COPB2','CKAP5']
model_path = '/content/drive/MyDrive/Colab Notebooks/Cas9/On target/saved_model/Cas9_MultiHeadAttention_weights.keras'

for gene in genes:
    gRNADesign_mutation(gene, vcf_reader, model_path, write_to_csv=True)

# %% [markdown]
# ##### Find difference

# %%
# example
model_path = '/content/drive/MyDrive/Colab Notebooks/Cas9/On target/saved_model/Transformer_withoutEpi_weights.keras'
pred_result_mut = gRNADesign_mutation('TROAP', vcf_reader, model_path, write_to_csv=False)

header = ['Gene','Chrom','Strand','Start','Transcript','Exon','Target sequence (5\' to 3\')','gRNA','pred_Score','Is_mutation']
table = tabulate.tabulate(pred_result_mut, header, tablefmt='pipe')
print(table)
# Out:
# | Gene   |   Chrom |   Strand | Start     | Transcript      | Exon            | Target sequence (5' to 3')   | gRNA                 |   pred_Score | Is_mutation   |
# |:-------|--------:|---------:|:----------|:----------------|:----------------|:-----------------------------|:---------------------|-------------:|:--------------|
# | TROAP  |      12 |        1 | 49323611  | ENST00000549275 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000549275 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000549275 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000551245 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000551245 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000551245 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000551245 | ENSE00003548436 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49329907  | ENST00000551245 | ENSE00000919621 | GGAGGGTTCTGGGAAACCACCGG      | GGAGGGUUCUGGGAAACCAC |  1           | False         |
# | TROAP  |      12 |        1 | 49329897  | ENST00000551245 | ENSE00000919621 | TAAGGTCACTGGAGGGTTCTGGG      | UAAGGUCACUGGAGGGUUCU |  1           | False         |
# | TROAP  |      12 |        1 | 49329958  | ENST00000551245 | ENSE00000919621 | CAGAACCCCCAGCCTCCAGGAGG      | CAGAACCCCCAGCCUCCAGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329910  | ENST00000551245 | ENSE00000919621 | GGGTTCTGGGAAACCACCGGTGG      | GGGUUCUGGGAAACCACCGG |  1           | False         |
# | TROAP  |      12 |        1 | 49330682  | ENST00000551245 | ENSE00002377270 | CCCTGCCCTCCAGCAGAACCCGG      | CCCUGCCCUCCAGCAGAACC |  1           | False         |
# | TROAP  |      12 |        1 | 49331006  | ENST00000551245 | ENSE00002377270 | ACCTGCCCTGCCCCTACCCCAGG      | ACCUGCCCUGCCCCUACCCC |  1           | False         |
# | TROAP  |      12 |        1 | 49331145  | ENST00000551245 | ENSE00002377270 | GAGGAGAGGACAGTACATGGTGG      | GAGGAGAGGACAGUACAUGG |  1           | False         |
# | TROAP  |      12 |        1 | 49330933  | ENST00000551245 | ENSE00002377270 | AGGCCAGGCAGGTAAGGAGTTGG      | AGGCCAGGCAGGUAAGGAGU |  1           | False         |
# | TROAP  |      12 |        1 | 49331356  | ENST00000551245 | ENSE00002377270 | CCGGGTCTGCACCAACCCTGTGG      | CCGGGUCUGCACCAACCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49331327  | ENST00000551245 | ENSE00002377270 | ACCAGCCGAGCCCCTCCCTCAGG      | ACCAGCCGAGCCCCUCCCUC |  1           | False         |
# | TROAP  |      12 |        1 | 49331118  | ENST00000551245 | ENSE00002377270 | TAATTGGCTTGGCCGTTGGTGGG      | UAAUUGGCUUGGCCGUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000380327 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000380327 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000380327 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49324305  | ENST00000380327 | ENSE00001520490 | GAGACCAGCCTGGATGACAGAGG      | GAGACCAGCCUGGAUGACAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000548311 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000548311 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000548311 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49324305  | ENST00000548311 | ENSE00002372726 | GAGACCAGCCTGGATGACAGAGG      | GAGACCAGCCUGGAUGACAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000549891 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000549891 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000549891 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49329567  | ENST00000549891 | ENSE00002429408 | TGTAATCCCAGCACTTTGGGAGG      | UGUAAUCCCAGCACUUUGGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329491  | ENST00000549891 | ENSE00002429408 | GCCCTGTGCTGCCAGCCTGGAGG      | GCCCUGUGCUGCCAGCCUGG |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000257909 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000257909 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000257909 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000257909 | ENSE00003548436 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49329910  | ENST00000257909 | ENSE00000919621 | GGGTTCTGGGAAACCACCGGTGG      | GGGUUCUGGGAAACCACCGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329958  | ENST00000257909 | ENSE00000919621 | CAGAACCCCCAGCCTCCAGGAGG      | CAGAACCCCCAGCCUCCAGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329897  | ENST00000257909 | ENSE00000919621 | TAAGGTCACTGGAGGGTTCTGGG      | UAAGGUCACUGGAGGGUUCU |  1           | False         |
# | TROAP  |      12 |        1 | 49329907  | ENST00000257909 | ENSE00000919621 | GGAGGGTTCTGGGAAACCACCGG      | GGAGGGUUCUGGGAAACCAC |  1           | False         |
# | TROAP  |      12 |        1 | 49330682  | ENST00000257909 | ENSE00000919622 | CCCTGCCCTCCAGCAGAACCCGG      | CCCUGCCCUCCAGCAGAACC |  1           | False         |
# | TROAP  |      12 |        1 | 49331356  | ENST00000257909 | ENSE00000919623 | CCGGGTCTGCACCAACCCTGTGG      | CCGGGUCUGCACCAACCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49331327  | ENST00000257909 | ENSE00000919623 | ACCAGCCGAGCCCCTCCCTCAGG      | ACCAGCCGAGCCCCUCCCUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000550346 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000550346 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000550346 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000550346 | ENSE00003548436 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000550709 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000550709 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000550709 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49324083  | ENST00000550709 | ENSE00002382979 | GGACTAGGAAGGGTAAAAGTGGG      | GGACUAGGAAGGGUAAAAGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323991  | ENST00000550709 | ENSE00002382979 | TAGCCCTAGGGGTCAAAATGTGG      | UAGCCCUAGGGGUCAAAAUG |  1           | False         |
# | TROAP  |      12 |        1 | 49324305  | ENST00000550709 | ENSE00002382979 | GAGACCAGCCTGGATGACAGAGG      | GAGACCAGCCUGGAUGACAG |  1           | False         |
# | TROAP  |      12 |        1 | 49324090  | ENST00000550709 | ENSE00002382979 | GAAGGGTAAAAGTGGGGTTTTGG      | GAAGGGUAAAAGUGGGGUUU |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000546735 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000546735 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000546735 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000546735 | ENSE00003644556 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49329491  | ENST00000546735 | ENSE00002373977 | GCCCTGTGCTGCCAGCCTGGAGG      | GCCCUGUGCUGCCAGCCUGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329567  | ENST00000546735 | ENSE00002373977 | TGTAATCCCAGCACTTTGGGAGG      | UGUAAUCCCAGCACUUUGGG |  1           | False         |
# | TROAP  |      12 |        1 | 49323991  | ENST00000549534 | ENSE00002388756 | TAGCCCTAGGGGTCAAAATGTGG      | UAGCCCUAGGGGUCAAAAUG |  1           | False         |
# | TROAP  |      12 |        1 | 49324083  | ENST00000549534 | ENSE00002388756 | GGACTAGGAAGGGTAAAAGTGGG      | GGACUAGGAAGGGUAAAAGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323734* | ENST00000549534 | ENSE00002388756 | GGAGAACCAAGATCCAAGGCAGG      | GGAGAACCAAGAUCCAAGGC |  1           | True          |
# | TROAP  |      12 |        1 | 49323730  | ENST00000549534 | ENSE00002388756 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49324305  | ENST00000549534 | ENSE00002388756 | GAGACCAGCCTGGATGACAGAGG      | GAGACCAGCCUGGAUGACAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000549534 | ENSE00002388756 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49324090  | ENST00000549534 | ENSE00002388756 | GAAGGGTAAAAGTGGGGTTTTGG      | GAAGGGUAAAAGUGGGGUUU |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000549534 | ENSE00002388756 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000546776 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000546776 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000546776 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000546776 | ENSE00003644556 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000551192 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000551192 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000551192 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000551192 | ENSE00003604809 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49329727  | ENST00000551192 | ENSE00002401430 | GCCCCTCCTAATGTACATCTAGG      | GCCCCUCCUAAUGUACAUCU |  1           | False         |
# | TROAP  |      12 |        1 | 49329491  | ENST00000551192 | ENSE00002401430 | GCCCTGTGCTGCCAGCCTGGAGG      | GCCCUGUGCUGCCAGCCUGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329567  | ENST00000551192 | ENSE00002401430 | TGTAATCCCAGCACTTTGGGAGG      | UGUAAUCCCAGCACUUUGGG |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000547807 | ENSE00000919611 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000547807 | ENSE00000919611 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000547807 | ENSE00000919611 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000547807 | ENSE00003548436 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49323413  | ENST00000551567 | ENSE00002327379 | GGGCCCGAGGGCGAAAGAGTAGG      | GGGCCCGAGGGCGAAAGAGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323611  | ENST00000551567 | ENSE00002327379 | GACCACCCGGCAAGCCACGAAGG      | GACCACCCGGCAAGCCACGA |  1           | False         |
# | TROAP  |      12 |        1 | 49323626  | ENST00000551567 | ENSE00002327379 | CACGAAGGATCCCCTCCTCCGGG      | CACGAAGGAUCCCCUCCUCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323730  | ENST00000551567 | ENSE00002327379 | ACCAGGAGAACCAAGATCCAAGG      | ACCAGGAGAACCAAGAUCCA |  1           | False         |
# | TROAP  |      12 |        1 | 49325776  | ENST00000548817 | ENSE00003644556 | CAGAACCCCCACCCACCGACTGG      | CAGAACCCCCACCCACCGAC |  1           | False         |
# | TROAP  |      12 |        1 | 49329958  | ENST00000547923 | ENSE00000919621 | CAGAACCCCCAGCCTCCAGGAGG      | CAGAACCCCCAGCCUCCAGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329897  | ENST00000547923 | ENSE00000919621 | TAAGGTCACTGGAGGGTTCTGGG      | UAAGGUCACUGGAGGGUUCU |  1           | False         |
# | TROAP  |      12 |        1 | 49329910  | ENST00000547923 | ENSE00000919621 | GGGTTCTGGGAAACCACCGGTGG      | GGGUUCUGGGAAACCACCGG |  1           | False         |
# | TROAP  |      12 |        1 | 49329907  | ENST00000547923 | ENSE00000919621 | GGAGGGTTCTGGGAAACCACCGG      | GGAGGGUUCUGGGAAACCAC |  1           | False         |
# | TROAP  |      12 |        1 | 49330682  | ENST00000547923 | ENSE00002374322 | CCCTGCCCTCCAGCAGAACCCGG      | CCCUGCCCUCCAGCAGAACC |  1           | False         |
# | TROAP  |      12 |        1 | 49331327  | ENST00000547923 | ENSE00000919623 | ACCAGCCGAGCCCCTCCCTCAGG      | ACCAGCCGAGCCCCUCCCUC |  1           | False         |
# | TROAP  |      12 |        1 | 49331356  | ENST00000547923 | ENSE00000919623 | CCGGGTCTGCACCAACCCTGTGG      | CCGGGUCUGCACCAACCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000549275 | ENSE00001060270 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000549275 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000551245 | ENSE00002352797 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000551245 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000551245 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000380327 | ENSE00002358876 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000380327 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000380327 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000548311 | ENSE00002358876 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000548311 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000548311 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000549891 | ENSE00002358876 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000549891 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000257909 | ENSE00002358876 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000257909 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000257909 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000550346 | ENSE00002371273 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000550346 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000550709 | ENSE00002419180 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000550709 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000550709 | ENSE00002382979 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49324073  | ENST00000550709 | ENSE00002382979 | GCTGAGTAGGGGACTAGGAAGGG      | GCUGAGUAGGGGACUAGGAA |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000546735 | ENSE00002419180 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000546735 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000549534 | ENSE00002391329 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000549534 | ENSE00002388756 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49324294* | ENST00000549534 | ENSE00002388756 | GCTCCTGGAAAGCCAGGAGTTGG      | GCUCCUGGAAAGCCAGGAGU |  1           | True          |
# | TROAP  |      12 |        1 | 49324073  | ENST00000549534 | ENSE00002388756 | GCTGAGTAGGGGACTAGGAAGGG      | GCUGAGUAGGGGACUAGGAA |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000549534 | ENSE00002388756 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000546776 | ENSE00002419563 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000546776 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323292  | ENST00000551192 | ENSE00002330420 | CGAGAGGGTCAGGAGAAAAGCGG      | CGAGAGGGUCAGGAGAAAAG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000551192 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000551192 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000547807 | ENSE00000919611 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000547807 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49323491  | ENST00000551567 | ENSE00002327379 | TGTGGGCGCGTGGATTAGGGCGG      | UGUGGGCGCGUGGAUUAGGG |  1           | False         |
# | TROAP  |      12 |        1 | 49323656  | ENST00000551567 | ENSE00002327379 | TCCTACCCCTAGCAAGATTCCGG      | UCCUACCCCUAGCAAGAUUC |  1           | False         |
# | TROAP  |      12 |        1 | 49323929  | ENST00000551567 | ENSE00001272372 | GAGACATCACAAAGATTGGTGGG      | GAGACAUCACAAAGAUUGGU |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000551245 | ENSE00003632936 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49330938  | ENST00000551245 | ENSE00002377270 | AGGCAGGTAAGGAGTTGGCTGGG      | AGGCAGGUAAGGAGUUGGCU |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000257909 | ENSE00003632936 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000550346 | ENSE00003632936 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49324062  | ENST00000550709 | ENSE00002382979 | CGGCCTCCATGGCTGAGTAGGGG      | CGGCCUCCAUGGCUGAGUAG |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000546735 | ENSE00003650795 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49324062  | ENST00000549534 | ENSE00002388756 | CGGCCTCCATGGCTGAGTAGGGG      | CGGCCUCCAUGGCUGAGUAG |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000546776 | ENSE00003650795 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000551192 | ENSE00003650795 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000547807 | ENSE00003632936 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49323420  | ENST00000551567 | ENSE00002327379 | AGGGCGAAAGAGTAGGCTCGGGG      | AGGGCGAAAGAGUAGGCUCG |  1           | False         |
# | TROAP  |      12 |        1 | 49326127  | ENST00000548817 | ENSE00003650795 | GAGCTAAGAAGGGAGACAGCTGG      | GAGCUAAGAAGGGAGACAGC |  1           | False         |
# | TROAP  |      12 |        1 | 49330485  | ENST00000551245 | ENSE00002377270 | CCTACCCTCCAGCAGAACCCAGG      | CCUACCCUCCAGCAGAACCC |  1           | False         |
# | TROAP  |      12 |        1 | 49330485  | ENST00000257909 | ENSE00000919622 | CCTACCCTCCAGCAGAACCCAGG      | CCUACCCUCCAGCAGAACCC |  1           | False         |
# | TROAP  |      12 |        1 | 49323473  | ENST00000551567 | ENSE00002327379 | TTGCAGGCGCCGGGGGCTTGTGG      | UUGCAGGCGCCGGGGGCUUG |  1           | False         |
# | TROAP  |      12 |        1 | 49330485  | ENST00000547923 | ENSE00002377859 | CCTACCCTCCAGCAGAACCCAGG      | CCUACCCUCCAGCAGAACCC |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000551245 | ENSE00003688930 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49330748  | ENST00000551245 | ENSE00002377270 | CCCTGCCCTAGGGTAGAGCTGGG      | CCCUGCCCUAGGGUAGAGCU |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000549891 | ENSE00003653778 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000257909 | ENSE00003688930 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49330748  | ENST00000257909 | ENSE00000919622 | CCCTGCCCTAGGGTAGAGCTGGG      | CCCUGCCCUAGGGUAGAGCU |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000546735 | ENSE00003653778 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000546776 | ENSE00002342429 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000551192 | ENSE00003653778 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49323474  | ENST00000551567 | ENSE00002327379 | TGCAGGCGCCGGGGGCTTGTGGG      | UGCAGGCGCCGGGGGCUUGU |  1           | False         |
# | TROAP  |      12 |        1 | 49328947  | ENST00000547923 | ENSE00003688930 | GATGCCCTCCCCTGCCCCTGTGG      | GAUGCCCUCCCCUGCCCCUG |  1           | False         |
# | TROAP  |      12 |        1 | 49330748  | ENST00000547923 | ENSE00002374322 | CCCTGCCCTAGGGTAGAGCTGGG      | CCCUGCCCUAGGGUAGAGCU |  1           | False         |
# | TROAP  |      12 |        1 | 49330353  | ENST00000551245 | ENSE00002377270 | CCTGTCTTCCAGAGGAGTGCGGG      | CCUGUCUUCCAGAGGAGUGC |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49329433  | ENST00000549891 | ENSE00002429408 | TGAAGATCCTGCCCTGCCCTGGG      | UGAAGAUCCUGCCCUGCCCU |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49330353  | ENST00000257909 | ENSE00000919622 | CCTGTCTTCCAGAGGAGTGCGGG      | CCUGUCUUCCAGAGGAGUGC |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49329433  | ENST00000546735 | ENSE00002373977 | TGAAGATCCTGCCCTGCCCTGGG      | UGAAGAUCCUGCCCUGCCCU |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49329433  | ENST00000551192 | ENSE00002401430 | TGAAGATCCTGCCCTGCCCTGGG      | UGAAGAUCCUGCCCUGCCCU |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49330353  | ENST00000547923 | ENSE00002377859 | CCTGTCTTCCAGAGGAGTGCGGG      | CCUGUCUUCCAGAGGAGUGC |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49323923* | ENST00000551245 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323923* | ENST00000380327 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323923* | ENST00000548311 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323923* | ENST00000257909 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49324084  | ENST00000550709 | ENSE00002382979 | GACTAGGAAGGGTAAAAGTGGGG      | GACUAGGAAGGGUAAAAGUG |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49324084  | ENST00000549534 | ENSE00002388756 | GACTAGGAAGGGTAAAAGTGGGG      | GACUAGGAAGGGUAAAAGUG |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49323923* | ENST00000551192 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323923* | ENST00000547807 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323923* | ENST00000551567 | ENSE00001272372 | CAGGCAGAGACATCACAAAGAGG      | CAGGCAGAGACAUCACAAAG |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323515  | ENST00000551567 | ENSE00002327379 | GGTATCAGGGATGGCAGGACAGG      | GGUAUCAGGGAUGGCAGGAC |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49323379  | ENST00000551567 | ENSE00002327379 | AGGCTGCTGGGTTCATAGGGAGG      | AGGCUGCUGGGUUCAUAGGG |  0.999999    | False         |
# | TROAP  |      12 |        1 | 49323934* | ENST00000551245 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323934* | ENST00000380327 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323934* | ENST00000548311 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323934* | ENST00000257909 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323934* | ENST00000551192 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323934* | ENST00000547807 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49323934* | ENST00000551567 | ENSE00001272372 | ATCACAAAGAGGCAGGCCCCAGG      | AUCACAAAGAGGCAGGCCCC |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000551245 | ENSE00003688930 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000549891 | ENSE00003653778 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000257909 | ENSE00003688930 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000546735 | ENSE00003653778 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000546776 | ENSE00002342429 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000551192 | ENSE00003653778 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49328997* | ENST00000547923 | ENSE00003688930 | CATGTCCATCACCTTTTGGACGG      | CAUGUCCAUCACCUUUUGGA |  0.999999    | True          |
# | TROAP  |      12 |        1 | 49330375  | ENST00000551245 | ENSE00002377270 | GGAACCACAGCCCTGCCCTCCGG      | GGAACCACAGCCCUGCCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49330375  | ENST00000257909 | ENSE00000919622 | GGAACCACAGCCCTGCCCTCCGG      | GGAACCACAGCCCUGCCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49330375  | ENST00000547923 | ENSE00002377859 | GGAACCACAGCCCTGCCCTCCGG      | GGAACCACAGCCCUGCCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000551245 | ENSE00003632936 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49331337  | ENST00000551245 | ENSE00002377270 | CCCCTCCCTCAGGCCCCACCCGG      | CCCCUCCCUCAGGCCCCACC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000257909 | ENSE00003632936 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49331337  | ENST00000257909 | ENSE00000919623 | CCCCTCCCTCAGGCCCCACCCGG      | CCCCUCCCUCAGGCCCCACC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000550346 | ENSE00003632936 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000546735 | ENSE00003650795 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000546776 | ENSE00003650795 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000551192 | ENSE00003650795 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000547807 | ENSE00003632936 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49326117  | ENST00000548817 | ENSE00003650795 | CAGTTTCCAGGAGCTAAGAAGGG      | CAGUUUCCAGGAGCUAAGAA |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49331337  | ENST00000547923 | ENSE00000919623 | CCCCTCCCTCAGGCCCCACCCGG      | CCCCUCCCUCAGGCCCCACC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000549275 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000551245 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000380327 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000548311 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000549891 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000257909 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000550346 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000550709 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000546735 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000549534 | ENSE00002388756 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000546776 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000551192 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000547807 | ENSE00000919611 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49323625  | ENST00000551567 | ENSE00002327379 | CCACGAAGGATCCCCTCCTCCGG      | CCACGAAGGAUCCCCUCCUC |  0.999998    | False         |
# | TROAP  |      12 |        1 | 49330771  | ENST00000551245 | ENSE00002377270 | GGCATCAGAGCCCTGCACCCTGG      | GGCAUCAGAGCCCUGCACCC |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49330771  | ENST00000257909 | ENSE00000919622 | GGCATCAGAGCCCTGCACCCTGG      | GGCAUCAGAGCCCUGCACCC |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49330771  | ENST00000547923 | ENSE00002374322 | GGCATCAGAGCCCTGCACCCTGG      | GGCAUCAGAGCCCUGCACCC |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000549275 | ENSE00001060270 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000551245 | ENSE00002352797 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000380327 | ENSE00002358876 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000548311 | ENSE00002358876 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000549891 | ENSE00002358876 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000257909 | ENSE00002358876 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000550346 | ENSE00002371273 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000550709 | ENSE00002419180 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000546735 | ENSE00002419180 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000549534 | ENSE00002391329 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000546776 | ENSE00002419563 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49323303  | ENST00000551192 | ENSE00002330420 | GGAGAAAAGCGGAGGAAGCTGGG      | GGAGAAAAGCGGAGGAAGCU |  0.999997    | False         |
# | TROAP  |      12 |        1 | 49324306  | ENST00000380327 | ENSE00001520490 | AGACCAGCCTGGATGACAGAGGG      | AGACCAGCCUGGAUGACAGA |  0.999996    | False         |
# | TROAP  |      12 |        1 | 49324306  | ENST00000548311 | ENSE00002372726 | AGACCAGCCTGGATGACAGAGGG      | AGACCAGCCUGGAUGACAGA |  0.999996    | False         |
# | TROAP  |      12 |        1 | 49324306  | ENST00000550709 | ENSE00002382979 | AGACCAGCCTGGATGACAGAGGG      | AGACCAGCCUGGAUGACAGA |  0.999996    | False         |
# | TROAP  |      12 |        1 | 49324306  | ENST00000549534 | ENSE00002388756 | AGACCAGCCTGGATGACAGAGGG      | AGACCAGCCUGGAUGACAGA |  0.999996    | False         |
# | TROAP  |      12 |        1 | 49323930* | ENST00000551245 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323930* | ENST00000380327 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323930* | ENST00000548311 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323930* | ENST00000257909 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323930* | ENST00000551192 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323930* | ENST00000547807 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323930* | ENST00000551567 | ENSE00001272372 | AGACATCACAAAGAGGAGATGGG      | AGACAUCACAAAGAGGAGAU |  0.999996    | True          |
# | TROAP  |      12 |        1 | 49323506  | ENST00000551567 | ENSE00002327379 | TAGGGCGGAGGTATCAGGGATGG      | UAGGGCGGAGGUAUCAGGGA |  0.999996    | False         |
# | TROAP  |      12 |        1 | 49323457  | ENST00000551567 | ENSE00002327379 | ACCCATAAGAGCGGTCTTGCAGG      | ACCCAUAAGAGCGGUCUUGC |  0.999995    | False         |
# | TROAP  |      12 |        1 | 49327309  | ENST00000550346 | ENSE00002402491 | CCGAGAAATGTCACATACCAGGG      | CCGAGAAAUGUCACAUACCA |  0.999995    | False         |
# | TROAP  |      12 |        1 | 49323668* | ENST00000549275 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000551245 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000380327 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000548311 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000549891 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000257909 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000550346 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000550709 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000546735 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323736* | ENST00000549534 | ENSE00002388756 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000546776 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000551192 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000547807 | ENSE00000919611 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000551567 | ENSE00002327379 | AGAACCAAGATCCAAGGAGATGG      | AGAACCAAGAUCCAAGGAGA |  0.999995    | True          |
# | TROAP  |      12 |        1 | 49331338  | ENST00000551245 | ENSE00002377270 | CCCTCCCTCAGGCCCCACCCGGG      | CCCUCCCUCAGGCCCCACCC |  0.999994    | False         |
# | TROAP  |      12 |        1 | 49331338  | ENST00000257909 | ENSE00000919623 | CCCTCCCTCAGGCCCCACCCGGG      | CCCUCCCUCAGGCCCCACCC |  0.999994    | False         |
# | TROAP  |      12 |        1 | 49331338  | ENST00000547923 | ENSE00000919623 | CCCTCCCTCAGGCCCCACCCGGG      | CCCUCCCUCAGGCCCCACCC |  0.999994    | False         |
# | TROAP  |      12 |        1 | 49330937  | ENST00000551245 | ENSE00002377270 | CAGGCAGGTAAGGAGTTGGCTGG      | CAGGCAGGUAAGGAGUUGGC |  0.999993    | False         |
# | TROAP  |      12 |        1 | 49323418  | ENST00000551567 | ENSE00002327379 | CGAGGGCGAAAGAGTAGGCTCGG      | CGAGGGCGAAAGAGUAGGCU |  0.999993    | False         |
# | TROAP  |      12 |        1 | 49323978  | ENST00000550709 | ENSE00002382979 | AAGAGCTCAGGCCTAGCCCTAGG      | AAGAGCUCAGGCCUAGCCCU |  0.999993    | False         |
# | TROAP  |      12 |        1 | 49323978  | ENST00000549534 | ENSE00002388756 | AAGAGCTCAGGCCTAGCCCTAGG      | AAGAGCUCAGGCCUAGCCCU |  0.999993    | False         |
# | TROAP  |      12 |        1 | 49323465  | ENST00000551567 | ENSE00002327379 | GAGCGGTCTTGCAGGCGCCGGGG      | GAGCGGUCUUGCAGGCGCCG |  0.999992    | False         |
# | TROAP  |      12 |        1 | 49330181* | ENST00000551245 | ENSE00002377270 | AGGAGGTAGAGGGGCTGGTAGGG      | AGGAGGUAGAGGGGCUGGUA |  0.999992    | True          |
# | TROAP  |      12 |        1 | 49330181* | ENST00000257909 | ENSE00000919622 | AGGAGGTAGAGGGGCTGGTAGGG      | AGGAGGUAGAGGGGCUGGUA |  0.999992    | True          |
# | TROAP  |      12 |        1 | 49330181* | ENST00000547923 | ENSE00002377859 | AGGAGGTAGAGGGGCTGGTAGGG      | AGGAGGUAGAGGGGCUGGUA |  0.999992    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000549275 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000551245 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000380327 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000548311 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000549891 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000257909 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000550346 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000550709 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000546735 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323737* | ENST00000549534 | ENSE00002388756 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000546776 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000551192 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000547807 | ENSE00000919611 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49323668* | ENST00000551567 | ENSE00002327379 | GAACCAAGATCCAAGGAGATGGG      | GAACCAAGAUCCAAGGAGAU |  0.999991    | True          |
# | TROAP  |      12 |        1 | 49330441  | ENST00000551245 | ENSE00002377270 | GATACCAGAGCCCTCCCTCCAGG      | GAUACCAGAGCCCUCCCUCC |  0.999991    | False         |
# ...
# | TROAP  |      12 |        1 | 49329523  | ENST00000549891 | ENSE00002429408 | TTGAGGCACACGTGCTTTCTGGG      | UUGAGGCACACGUGCUUUCU |  0.0018069   | False         |
# | TROAP  |      12 |        1 | 49329523  | ENST00000546735 | ENSE00002373977 | TTGAGGCACACGTGCTTTCTGGG      | UUGAGGCACACGUGCUUUCU |  0.0018069   | False         |
# | TROAP  |      12 |        1 | 49329523  | ENST00000551192 | ENSE00002401430 | TTGAGGCACACGTGCTTTCTGGG      | UUGAGGCACACGUGCUUUCU |  0.0018069   | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000551245 | ENSE00003548436 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000257909 | ENSE00003548436 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000550346 | ENSE00003548436 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000546735 | ENSE00003644556 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000546776 | ENSE00003644556 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000551192 | ENSE00003604809 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000547807 | ENSE00003548436 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49325749  | ENST00000548817 | ENSE00003644556 | TGTTCGGGCCTCTGCATATTTGG      | UGUUCGGGCCUCUGCAUAUU |  0.00144753  | False         |
# | TROAP  |      12 |        1 | 49329522  | ENST00000549891 | ENSE00002429408 | TTTGAGGCACACGTGCTTTCTGG      | UUUGAGGCACACGUGCUUUC |  0.00108837  | False         |
# | TROAP  |      12 |        1 | 49329522  | ENST00000546735 | ENSE00002373977 | TTTGAGGCACACGTGCTTTCTGG      | UUUGAGGCACACGUGCUUUC |  0.00108837  | False         |
# | TROAP  |      12 |        1 | 49329522  | ENST00000551192 | ENSE00002401430 | TTTGAGGCACACGTGCTTTCTGG      | UUUGAGGCACACGUGCUUUC |  0.00108837  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000551245 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000380327 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000548311 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000257909 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000550709 | ENSE00002382979 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000549534 | ENSE00002388756 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000546776 | ENSE00002407227 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000551192 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000547807 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49323878  | ENST00000551567 | ENSE00001272372 | CGCCCCCTCGTTGATTCAGCAGG      | CGCCCCCUCGUUGAUUCAGC |  0.00096765  | False         |
# | TROAP  |      12 |        1 | 49329528  | ENST00000549891 | ENSE00002429408 | GCACACGTGCTTTCTGGGCCAGG      | GCACACGUGCUUUCUGGGCC |  0.00083235  | False         |
# | TROAP  |      12 |        1 | 49329528  | ENST00000546735 | ENSE00002373977 | GCACACGTGCTTTCTGGGCCAGG      | GCACACGUGCUUUCUGGGCC |  0.00083235  | False         |
# | TROAP  |      12 |        1 | 49329528  | ENST00000551192 | ENSE00002401430 | GCACACGTGCTTTCTGGGCCAGG      | GCACACGUGCUUUCUGGGCC |  0.00083235  | False         |
# | TROAP  |      12 |        1 | 49324160* | ENST00000549534 | ENSE00002388756 | GTCCCAGCTCCTGGAAAGCCAGG      | GUCCCAGCUCCUGGAAAGCC |  0.000828128 | True          |
# | TROAP  |      12 |        1 | 49323998  | ENST00000550709 | ENSE00002382979 | AGGGGTCAAAATGTGGGGCCTGG      | AGGGGUCAAAAUGUGGGGCC |  0.000743264 | False         |
# | TROAP  |      12 |        1 | 49323998  | ENST00000549534 | ENSE00002388756 | AGGGGTCAAAATGTGGGGCCTGG      | AGGGGUCAAAAUGUGGGGCC |  0.000743264 | False         |
# | TROAP  |      12 |        1 | 49325565  | ENST00000551245 | ENSE00003630451 | GGGTGTGAAGAGCTGTCACCTGG      | GGGUGUGAAGAGCUGUCACC |  0.000542204 | False         |
# | TROAP  |      12 |        1 | 49325565  | ENST00000257909 | ENSE00003630451 | GGGTGTGAAGAGCTGTCACCTGG      | GGGUGUGAAGAGCUGUCACC |  0.000542204 | False         |
# | TROAP  |      12 |        1 | 49325565  | ENST00000546735 | ENSE00003632906 | GGGTGTGAAGAGCTGTCACCTGG      | GGGUGUGAAGAGCUGUCACC |  0.000542204 | False         |
# | TROAP  |      12 |        1 | 49325565  | ENST00000546776 | ENSE00003632906 | GGGTGTGAAGAGCTGTCACCTGG      | GGGUGUGAAGAGCUGUCACC |  0.000542204 | False         |
# | TROAP  |      12 |        1 | 49325565  | ENST00000547807 | ENSE00003630451 | GGGTGTGAAGAGCTGTCACCTGG      | GGGUGUGAAGAGCUGUCACC |  0.000542204 | False         |
# | TROAP  |      12 |        1 | 49325565  | ENST00000548817 | ENSE00002396943 | GGGTGTGAAGAGCTGTCACCTGG      | GGGUGUGAAGAGCUGUCACC |  0.000542204 | False         |
# | TROAP  |      12 |        1 | 49330181* | ENST00000551245 | ENSE00002377270 | CAGGAGGTAGAGGGGCTGGTAGG      | CAGGAGGUAGAGGGGCUGGU |  0.000412623 | True          |
# | TROAP  |      12 |        1 | 49330181* | ENST00000257909 | ENSE00000919622 | CAGGAGGTAGAGGGGCTGGTAGG      | CAGGAGGUAGAGGGGCUGGU |  0.000412623 | True          |
# | TROAP  |      12 |        1 | 49330181* | ENST00000547923 | ENSE00002377859 | CAGGAGGTAGAGGGGCTGGTAGG      | CAGGAGGUAGAGGGGCUGGU |  0.000412623 | True          |
# | TROAP  |      12 |        1 | 49323463  | ENST00000551567 | ENSE00002327379 | AAGAGCGGTCTTGCAGGCGCCGG      | AAGAGCGGUCUUGCAGGCGC |  0.000395892 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000551245 | ENSE00003632936 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000257909 | ENSE00003632936 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000550346 | ENSE00003632936 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000546735 | ENSE00003650795 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000546776 | ENSE00003650795 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000551192 | ENSE00003650795 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000547807 | ENSE00003632936 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49326105  | ENST00000548817 | ENSE00003650795 | TTCCACTCGCCCCAGTTTCCAGG      | UUCCACUCGCCCCAGUUUCC |  0.000282247 | False         |
# | TROAP  |      12 |        1 | 49331114  | ENST00000551245 | ENSE00002377270 | CTCCTAATTGGCTTGGCCGTTGG      | CUCCUAAUUGGCUUGGCCGU |  0.000219348 | False         |
# | TROAP  |      12 |        1 | 49329742  | ENST00000551192 | ENSE00002401430 | CATCTAGGGCCTCTCAGTTAGGG      | CAUCUAGGGCCUCUCAGUUA |  0.000112617 | False         |
# | TROAP  |      12 |        1 | 49331066  | ENST00000551245 | ENSE00002377270 | CTGGCTCTCCCTCAGGAAGAGGG      | CUGGCUCUCCCUCAGGAAGA |  0.000110945 | False         |
# | TROAP  |      12 |        1 | 49329488  | ENST00000549891 | ENSE00002429408 | CTTGCCCTGTGCTGCCAGCCTGG      | CUUGCCCUGUGCUGCCAGCC |  9.58683e-05 | False         |
# | TROAP  |      12 |        1 | 49329488  | ENST00000546735 | ENSE00002373977 | CTTGCCCTGTGCTGCCAGCCTGG      | CUUGCCCUGUGCUGCCAGCC |  9.58683e-05 | False         |
# | TROAP  |      12 |        1 | 49329488  | ENST00000551192 | ENSE00002401430 | CTTGCCCTGTGCTGCCAGCCTGG      | CUUGCCCUGUGCUGCCAGCC |  9.58683e-05 | False         |
# | TROAP  |      12 |        1 | 49330301  | ENST00000551245 | ENSE00002377270 | TCTGGGACTTCCCACCTTCCTGG      | UCUGGGACUUCCCACCUUCC |  9.28157e-05 | False         |
# | TROAP  |      12 |        1 | 49330301  | ENST00000257909 | ENSE00000919622 | TCTGGGACTTCCCACCTTCCTGG      | UCUGGGACUUCCCACCUUCC |  9.28157e-05 | False         |
# | TROAP  |      12 |        1 | 49330301  | ENST00000547923 | ENSE00002377859 | TCTGGGACTTCCCACCTTCCTGG      | UCUGGGACUUCCCACCUUCC |  9.28157e-05 | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000551245 | ENSE00003548436 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000257909 | ENSE00003548436 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000550346 | ENSE00003548436 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000546735 | ENSE00003644556 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000546776 | ENSE00003644556 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000551192 | ENSE00003604809 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000547807 | ENSE00003548436 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49325813  | ENST00000548817 | ENSE00003644556 | TCCTGCTTCTCTAGGCTGGAGGG      | UCCUGCUUCUCUAGGCUGGA |  8.7097e-05  | False         |
# | TROAP  |      12 |        1 | 49330156  | ENST00000551245 | ENSE00002377270 | CCTGCAACAGCTGTTGAGACAGG      | CCUGCAACAGCUGUUGAGAC |  7.33292e-05 | False         |
# | TROAP  |      12 |        1 | 49330156  | ENST00000257909 | ENSE00000919622 | CCTGCAACAGCTGTTGAGACAGG      | CCUGCAACAGCUGUUGAGAC |  7.33292e-05 | False         |
# | TROAP  |      12 |        1 | 49330156  | ENST00000547923 | ENSE00002377859 | CCTGCAACAGCTGTTGAGACAGG      | CCUGCAACAGCUGUUGAGAC |  7.33292e-05 | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000551245 | ENSE00003632936 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000257909 | ENSE00003632936 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000550346 | ENSE00003632936 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000546735 | ENSE00003650795 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000546776 | ENSE00003650795 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000551192 | ENSE00003650795 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000547807 | ENSE00003632936 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49326116  | ENST00000548817 | ENSE00003650795 | CCAGTTTCCAGGAGCTAAGAAGG      | CCAGUUUCCAGGAGCUAAGA |  6.8744e-05  | False         |
# | TROAP  |      12 |        1 | 49331373  | ENST00000551245 | ENSE00002377270 | CTGTGGCTACATTACTCGAATGG      | CUGUGGCUACAUUACUCGAA |  5.47994e-05 | False         |
# | TROAP  |      12 |        1 | 49331373  | ENST00000257909 | ENSE00000919623 | CTGTGGCTACATTACTCGAATGG      | CUGUGGCUACAUUACUCGAA |  5.47994e-05 | False         |
# | TROAP  |      12 |        1 | 49331373  | ENST00000547923 | ENSE00000919623 | CTGTGGCTACATTACTCGAATGG      | CUGUGGCUACAUUACUCGAA |  5.47994e-05 | False         |
# | TROAP  |      12 |        1 | 49329563  | ENST00000549891 | ENSE00002429408 | CACCTGTAATCCCAGCACTTTGG      | CACCUGUAAUCCCAGCACUU |  3.57856e-05 | False         |
# | TROAP  |      12 |        1 | 49329563  | ENST00000546735 | ENSE00002373977 | CACCTGTAATCCCAGCACTTTGG      | CACCUGUAAUCCCAGCACUU |  3.57856e-05 | False         |
# | TROAP  |      12 |        1 | 49329563  | ENST00000551192 | ENSE00002401430 | CACCTGTAATCCCAGCACTTTGG      | CACCUGUAAUCCCAGCACUU |  3.57856e-05 | False         |
# | TROAP  |      12 |        1 | 49329865  | ENST00000551245 | ENSE00000919621 | TGCCGTCCGGTTGTTTGACCAGG      | UGCCGUCCGGUUGUUUGACC |  3.28423e-05 | False         |
# | TROAP  |      12 |        1 | 49329865  | ENST00000257909 | ENSE00000919621 | TGCCGTCCGGTTGTTTGACCAGG      | UGCCGUCCGGUUGUUUGACC |  3.28423e-05 | False         |
# | TROAP  |      12 |        1 | 49329865  | ENST00000547923 | ENSE00000919621 | TGCCGTCCGGTTGTTTGACCAGG      | UGCCGUCCGGUUGUUUGACC |  3.28423e-05 | False         |
# | TROAP  |      12 |        1 | 49331670  | ENST00000257909 | ENSE00001060271 | TGTCGGTCTGCCCATGGGACTGG      | UGUCGGUCUGCCCAUGGGAC |  2.36088e-05 | False         |
# | TROAP  |      12 |        1 | 49331670  | ENST00000547923 | ENSE00002399498 | TGTCGGTCTGCCCATGGGACTGG      | UGUCGGUCUGCCCAUGGGAC |  2.36088e-05 | False         |
# | TROAP  |      12 |        1 | 49329497  | ENST00000549891 | ENSE00002429408 | TGCTGCCAGCCTGGAGGCCCAGG      | UGCUGCCAGCCUGGAGGCCC |  1.69388e-05 | False         |
# | TROAP  |      12 |        1 | 49329497  | ENST00000546735 | ENSE00002373977 | TGCTGCCAGCCTGGAGGCCCAGG      | UGCUGCCAGCCUGGAGGCCC |  1.69388e-05 | False         |
# | TROAP  |      12 |        1 | 49329497  | ENST00000551192 | ENSE00002401430 | TGCTGCCAGCCTGGAGGCCCAGG      | UGCUGCCAGCCUGGAGGCCC |  1.69388e-05 | False         |
# | TROAP  |      12 |        1 | 49324016  | ENST00000550709 | ENSE00002382979 | CCTGGGCCCCCTGCCCAGACAGG      | CCUGGGCCCCCUGCCCAGAC |  1.63015e-06 | False         |
# | TROAP  |      12 |        1 | 49324016  | ENST00000549534 | ENSE00002388756 | CCTGGGCCCCCTGCCCAGACAGG      | CCUGGGCCCCCUGCCCAGAC |  1.63015e-06 | False         |
# | TROAP  |      12 |        1 | 49329890  | ENST00000551245 | ENSE00000919621 | AGTTGTATAAGGTCACTGGAGGG      | AGUUGUAUAAGGUCACUGGA |  1.06465e-06 | False         |
# | TROAP  |      12 |        1 | 49329890  | ENST00000257909 | ENSE00000919621 | AGTTGTATAAGGTCACTGGAGGG      | AGUUGUAUAAGGUCACUGGA |  1.06465e-06 | False         |
# | TROAP  |      12 |        1 | 49329890  | ENST00000547923 | ENSE00000919621 | AGTTGTATAAGGTCACTGGAGGG      | AGUUGUAUAAGGUCACUGGA |  1.06465e-06 | False         |
# | TROAP  |      12 |        1 | 49331206  | ENST00000551245 | ENSE00002377270 | CCCCTCAGGCCTCAGCAATCTGG      | CCCCUCAGGCCUCAGCAAUC |  4.56052e-09 | False         |

# %%
# compare with no mutation
pred_result = gRNADesign('TROAP', model_path, write_to_csv=False)

output_exclude = []
for tar in pred_result:
    if tar[6] not in [item[6] for item in pred_result_mut]:
        output_exclude.append(tar)

header = ['Chrom','Start','End','Strand','Transcript','Exon','Target sequence (5\' to 3\')','gRNA','pred_Score']
print(tabulate.tabulate(output_exclude, header, tablefmt='pipe'))
# Out:
# |   Chrom |    Start |      End |   Strand | Transcript      | Exon            | Target sequence (5' to 3')   | gRNA                 |   pred_Score |
# |--------:|---------:|---------:|---------:|:----------------|:----------------|:-----------------------------|:---------------------|-------------:|
# |      12 | 49328997 | 49329019 |        1 | ENST00000551245 | ENSE00003688930 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49330176 | 49330198 |        1 | ENST00000551245 | ENSE00002377270 | AGGAAGTAGAGGGGCTGGTAGGG      | AGGAAGUAGAGGGGCUGGUA |  1           |
# |      12 | 49328997 | 49329019 |        1 | ENST00000549891 | ENSE00003653778 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49328997 | 49329019 |        1 | ENST00000257909 | ENSE00003688930 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49330176 | 49330198 |        1 | ENST00000257909 | ENSE00000919622 | AGGAAGTAGAGGGGCTGGTAGGG      | AGGAAGUAGAGGGGCUGGUA |  1           |
# |      12 | 49328997 | 49329019 |        1 | ENST00000546735 | ENSE00003653778 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49323751 | 49323773 |        1 | ENST00000549534 | ENSE00002388756 | GGGTAAGAGGGGCCTAATGGGGG      | GGGUAAGAGGGGCCUAAUGG |  1           |
# |      12 | 49328997 | 49329019 |        1 | ENST00000546776 | ENSE00002342429 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49328997 | 49329019 |        1 | ENST00000551192 | ENSE00003653778 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49328997 | 49329019 |        1 | ENST00000547923 | ENSE00003688930 | CATGTCCATCACCCTTTGGACGG      | CAUGUCCAUCACCCUUUGGA |  1           |
# |      12 | 49330176 | 49330198 |        1 | ENST00000547923 | ENSE00002377859 | AGGAAGTAGAGGGGCTGGTAGGG      | AGGAAGUAGAGGGGCUGGUA |  1           |
# |      12 | 49329615 | 49329637 |        1 | ENST00000551192 | ENSE00002401430 | CAGATCTTTGAGACCAGCCTGGG      | CAGAUCUUUGAGACCAGCCU |  0.999997    |
# |      12 | 49323731 | 49323753 |        1 | ENST00000549534 | ENSE00002388756 | CCAGGAGAACCAAGATCCAAGGG      | CCAGGAGAACCAAGAUCCAA |  0.999995    |
# |      12 | 49330165 | 49330187 |        1 | ENST00000551245 | ENSE00002377270 | GCTGTTGAGACAGGAAGTAGAGG      | GCUGUUGAGACAGGAAGUAG |  0.999995    |
# |      12 | 49330165 | 49330187 |        1 | ENST00000257909 | ENSE00000919622 | GCTGTTGAGACAGGAAGTAGAGG      | GCUGUUGAGACAGGAAGUAG |  0.999995    |
# |      12 | 49330165 | 49330187 |        1 | ENST00000547923 | ENSE00002377859 | GCTGTTGAGACAGGAAGTAGAGG      | GCUGUUGAGACAGGAAGUAG |  0.999995    |
# |      12 | 49330171 | 49330193 |        1 | ENST00000551245 | ENSE00002377270 | GAGACAGGAAGTAGAGGGGCTGG      | GAGACAGGAAGUAGAGGGGC |  0.999059    |
# |      12 | 49330171 | 49330193 |        1 | ENST00000257909 | ENSE00000919622 | GAGACAGGAAGTAGAGGGGCTGG      | GAGACAGGAAGUAGAGGGGC |  0.999059    |
# |      12 | 49330171 | 49330193 |        1 | ENST00000547923 | ENSE00002377859 | GAGACAGGAAGTAGAGGGGCTGG      | GAGACAGGAAGUAGAGGGGC |  0.999059    |
# |      12 | 49323739 | 49323761 |        1 | ENST00000549534 | ENSE00002388756 | ACCAAGATCCAAGGGTAAGAGGG      | ACCAAGAUCCAAGGGUAAGA |  0.998018    |
# |      12 | 49323748 | 49323770 |        1 | ENST00000549534 | ENSE00002388756 | CAAGGGTAAGAGGGGCCTAATGG      | CAAGGGUAAGAGGGGCCUAA |  0.997124    |
# |      12 | 49323738 | 49323760 |        1 | ENST00000549534 | ENSE00002388756 | AACCAAGATCCAAGGGTAAGAGG      | AACCAAGAUCCAAGGGUAAG |  0.996741    |
# |      12 | 49330178 | 49330200 |        1 | ENST00000551245 | ENSE00002377270 | GAAGTAGAGGGGCTGGTAGGGGG      | GAAGUAGAGGGGCUGGUAGG |  0.993394    |
# |      12 | 49330178 | 49330200 |        1 | ENST00000257909 | ENSE00000919622 | GAAGTAGAGGGGCTGGTAGGGGG      | GAAGUAGAGGGGCUGGUAGG |  0.993394    |
# |      12 | 49330178 | 49330200 |        1 | ENST00000547923 | ENSE00002377859 | GAAGTAGAGGGGCTGGTAGGGGG      | GAAGUAGAGGGGCUGGUAGG |  0.993394    |
# |      12 | 49330177 | 49330199 |        1 | ENST00000551245 | ENSE00002377270 | GGAAGTAGAGGGGCTGGTAGGGG      | GGAAGUAGAGGGGCUGGUAG |  0.991379    |
# |      12 | 49330177 | 49330199 |        1 | ENST00000257909 | ENSE00000919622 | GGAAGTAGAGGGGCTGGTAGGGG      | GGAAGUAGAGGGGCUGGUAG |  0.991379    |
# |      12 | 49330177 | 49330199 |        1 | ENST00000547923 | ENSE00002377859 | GGAAGTAGAGGGGCTGGTAGGGG      | GGAAGUAGAGGGGCUGGUAG |  0.991379    |
# |      12 | 49330166 | 49330188 |        1 | ENST00000551245 | ENSE00002377270 | CTGTTGAGACAGGAAGTAGAGGG      | CUGUUGAGACAGGAAGUAGA |  0.987785    |
# |      12 | 49330166 | 49330188 |        1 | ENST00000257909 | ENSE00000919622 | CTGTTGAGACAGGAAGTAGAGGG      | CUGUUGAGACAGGAAGUAGA |  0.987785    |
# |      12 | 49330166 | 49330188 |        1 | ENST00000547923 | ENSE00002377859 | CTGTTGAGACAGGAAGTAGAGGG      | CUGUUGAGACAGGAAGUAGA |  0.987785    |
# |      12 | 49323750 | 49323772 |        1 | ENST00000549534 | ENSE00002388756 | AGGGTAAGAGGGGCCTAATGGGG      | AGGGUAAGAGGGGCCUAAUG |  0.983236    |
# |      12 | 49323829 | 49323851 |        1 | ENST00000549534 | ENSE00002388756 | CCGCTCCCTCCCCTAGAGATGGG      | CCGCUCCCUCCCCUAGAGAU |  0.954155    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000551245 | ENSE00003688930 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000549891 | ENSE00003653778 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000257909 | ENSE00003688930 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000546735 | ENSE00003653778 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000546776 | ENSE00002342429 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000551192 | ENSE00003653778 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49328998 | 49329020 |        1 | ENST00000547923 | ENSE00003688930 | ATGTCCATCACCCTTTGGACGGG      | AUGUCCAUCACCCUUUGGAC |  0.944674    |
# |      12 | 49331154 | 49331176 |        1 | ENST00000551245 | ENSE00002377270 | ACAGTACATGGTGGAAGTATAGG      | ACAGUACAUGGUGGAAGUAU |  0.90205     |
# |      12 | 49328993 | 49329015 |        1 | ENST00000551245 | ENSE00003688930 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49328993 | 49329015 |        1 | ENST00000549891 | ENSE00003653778 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49328993 | 49329015 |        1 | ENST00000257909 | ENSE00003688930 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49328993 | 49329015 |        1 | ENST00000546735 | ENSE00003653778 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49328993 | 49329015 |        1 | ENST00000546776 | ENSE00002342429 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49328993 | 49329015 |        1 | ENST00000551192 | ENSE00003653778 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49328993 | 49329015 |        1 | ENST00000547923 | ENSE00003688930 | GTGCCATGTCCATCACCCTTTGG      | GUGCCAUGUCCAUCACCCUU |  0.888538    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000551245 | ENSE00003516458 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000549891 | ENSE00003493670 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000257909 | ENSE00003516458 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000550346 | ENSE00002402491 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000546735 | ENSE00003493670 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000546776 | ENSE00003493670 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000551192 | ENSE00003493670 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49327216 | 49327238 |        1 | ENST00000547923 | ENSE00003534769 | TCTTCCTAAAGGAGAACGCGAGG      | UCUUCCUAAAGGAGAACGCG |  0.820557    |
# |      12 | 49323740 | 49323762 |        1 | ENST00000549534 | ENSE00002388756 | CCAAGATCCAAGGGTAAGAGGGG      | CCAAGAUCCAAGGGUAAGAG |  0.442259    |
# |      12 | 49329614 | 49329636 |        1 | ENST00000551192 | ENSE00002401430 | TCAGATCTTTGAGACCAGCCTGG      | UCAGAUCUUUGAGACCAGCC |  0.141947    |
# |      12 | 49330175 | 49330197 |        1 | ENST00000551245 | ENSE00002377270 | CAGGAAGTAGAGGGGCTGGTAGG      | CAGGAAGUAGAGGGGCUGGU |  0.120324    |
# |      12 | 49330175 | 49330197 |        1 | ENST00000257909 | ENSE00000919622 | CAGGAAGTAGAGGGGCTGGTAGG      | CAGGAAGUAGAGGGGCUGGU |  0.120324    |
# |      12 | 49330175 | 49330197 |        1 | ENST00000547923 | ENSE00002377859 | CAGGAAGTAGAGGGGCTGGTAGG      | CAGGAAGUAGAGGGGCUGGU |  0.120324    |
# |      12 | 49330167 | 49330189 |        1 | ENST00000551245 | ENSE00002377270 | TGTTGAGACAGGAAGTAGAGGGG      | UGUUGAGACAGGAAGUAGAG |  0.0788457   |
# |      12 | 49330167 | 49330189 |        1 | ENST00000257909 | ENSE00000919622 | TGTTGAGACAGGAAGTAGAGGGG      | UGUUGAGACAGGAAGUAGAG |  0.0788457   |
# |      12 | 49330167 | 49330189 |        1 | ENST00000547923 | ENSE00002377859 | TGTTGAGACAGGAAGTAGAGGGG      | UGUUGAGACAGGAAGUAGAG |  0.0788457   |
# |      12 | 49323828 | 49323850 |        1 | ENST00000549534 | ENSE00002388756 | CCCGCTCCCTCCCCTAGAGATGG      | CCCGCUCCCUCCCCUAGAGA |  0.044996    |
# |      12 | 49329034 | 49329056 |        1 | ENST00000546776 | ENSE00002342429 | CTCCCCAGGCCCTCCAACTCTGG      | CUCCCCAGGCCCUCCAACUC |  0.00038919  |
# |      12 | 49323749 | 49323771 |        1 | ENST00000549534 | ENSE00002388756 | AAGGGTAAGAGGGGCCTAATGGG      | AAGGGUAAGAGGGGCCUAAU |  0.000108887 |

# %% [markdown]
# ### Evaluate performance by comparing to Depmap

# %%
# read Depmap data
sgRNA_breast_cancer_DepMap = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/CRISPR_data/sgRNA_breast_cancer_DepMap.xlsx')
sgRNA_breast_cancer_DepMap
# Out:
#        sgRNA_data_ID     Construct Barcode sgRNA_annotation_breast_sgRNA  \
# 0              60396  TATTGGATACAAAGCAAAAG          TATTGGATACAAAGCAAAAG
# 1              60396  TATTGGATACAAAGCAAAAG          TATTGGATACAAAGCAAAAG
# 2              60396  TATTGGATACAAAGCAAAAG          TATTGGATACAAAGCAAAAG
# 3              60396  TATTGGATACAAAGCAAAAG          TATTGGATACAAAGCAAAAG
# 4              60396  TATTGGATACAAAGCAAAAG          TATTGGATACAAAGCAAAAG
# ...              ...                   ...                           ...
# 81428          73821  TTTGTGTATTACCTCAGGAA                           NaN
# 81429          73839  TTTTACCTTGTTCACATGGA                           NaN
# 81430          73840  TTTTGACTCTAATCACCGGT                           NaN
# 81431          73841  TTTTTAATACAAGGTAATCT                           NaN
# 81432          73842  TTTTTCTCACCCGATGAATC                           NaN
#
#         genome_alignment guide_gene_map_gene  n_alignments  \
# 0      chr10_135118908_-                 NaN          69.0
# 1      chr10_134957906_-                 NaN          69.0
# 2       chr3_195749617_-                 NaN          69.0
# 3       chr2_153612203_-                 NaN          69.0
# 4       chr19_42304731_-                 NaN          69.0
# ...                  ...                 ...           ...
# 81428                NaN                 NaN           NaN
# 81429                NaN                 NaN           NaN
# 81430                NaN                 NaN           NaN
# 81431                NaN                 NaN           NaN
# 81432                NaN                 NaN           NaN
#
#        guide_efficacy_sgRNA  efficacy  MDAMB231-311Cas9_RepA_p5_batch2  \
# 0      TATTGGATACAAAGCAAAAG  0.686422                        -3.225385
# 1      TATTGGATACAAAGCAAAAG  0.686422                        -3.225385
# 2      TATTGGATACAAAGCAAAAG  0.686422                        -3.225385
# 3      TATTGGATACAAAGCAAAAG  0.686422                        -3.225385
# 4      TATTGGATACAAAGCAAAAG  0.686422                        -3.225385
# ...                     ...       ...                              ...
# 81428                   NaN       NaN                        -0.069900
# 81429  TTTTACCTTGTTCACATGGA       NaN                         1.115169
# 81430  TTTTGACTCTAATCACCGGT       NaN                         0.757864
# 81431  TTTTTAATACAAGGTAATCT       NaN                         1.460283
# 81432  TTTTTCTCACCCGATGAATC       NaN                         1.241231
#
#        MDAMB231-311Cas9_RepB_p5_batch2  ...  MDAMB436-311cas9 Rep B p5_batch2  \
# 0                            -3.071423  ...                         -1.594764
# 1                            -3.071423  ...                         -1.594764
# 2                            -3.071423  ...                         -1.594764
# 3                            -3.071423  ...                         -1.594764
# 4                            -3.071423  ...                         -1.594764
# ...                                ...  ...                               ...
# 81428                         0.437790  ...                          0.572026
# 81429                         1.066007  ...                          0.944632
# 81430                         0.658191  ...                          0.351637
# 81431                         1.095231  ...                          1.205029
# 81432                         1.010093  ...                          0.929043
#
#        MDAMB436-311cas9 Rep C p5_batch2  MDAMB453-311Cas9_RepA_p5_batch2  \
# 0                             -3.158211                        -2.187555
# 1                             -3.158211                        -2.187555
# 2                             -3.158211                        -2.187555
# 3                             -3.158211                        -2.187555
# 4                             -3.158211                        -2.187555
# ...                                 ...                              ...
# 81428                          0.995102                        -0.003004
# 81429                          0.983323                         0.481378
# 81430                          0.611574                         0.331574
# 81431                          0.976688                         0.598391
# 81432                          0.462104                         0.858101
#
#        MDAMB453-311Cas9_RepB_p5_batch2  MDAMB453-311Cas9_RepC_p5_batch2  \
# 0                            -1.904303                        -2.228527
# 1                            -1.904303                        -2.228527
# 2                            -1.904303                        -2.228527
# 3                            -1.904303                        -2.228527
# 4                            -1.904303                        -2.228527
# ...                                ...                              ...
# 81428                        -0.335238                         0.006941
# 81429                         0.640064                         0.978568
# 81430                         0.615665                         0.917588
# 81431                         0.797775                         1.323785
# 81432                         0.702916                         0.834095
#
#        MDAMB468-311cas9_RepB_p6_batch2  SKBR3-311Cas9_RepA_p6_batch3  \
# 0                            -3.255427                     -2.096329
# 1                            -3.255427                     -2.096329
# 2                            -3.255427                     -2.096329
# 3                            -3.255427                     -2.096329
# 4                            -3.255427                     -2.096329
# ...                                ...                           ...
# 81428                         0.613603                     -0.134402
# 81429                         0.845937                      0.306001
# 81430                         0.438363                      0.237336
# 81431                         0.799345                      0.330981
# 81432                         0.304551                      0.205100
#
#        SKBR3-311Cas9_RepB_p6_batch3  ZR-75-1-311Cas9_RepA_p5_batch2  \
# 0                         -1.728541                       -3.003000
# 1                         -1.728541                       -3.003000
# 2                         -1.728541                       -3.003000
# 3                         -1.728541                       -3.003000
# 4                         -1.728541                       -3.003000
# ...                             ...                             ...
# 81428                      0.126074                       -0.172093
# 81429                      0.489620                        0.972101
# 81430                      0.501745                        0.469061
# 81431                      0.095441                        1.104013
# 81432                      0.093559                        1.142008
#
#        ZR-75-1-311Cas9_RepB_p5_batch2
# 0                           -2.834542
# 1                           -2.834542
# 2                           -2.834542
# 3                           -2.834542
# 4                           -2.834542
# ...                               ...
# 81428                        0.557233
# 81429                        1.319258
# 81430                        0.826546
# 81431                        0.911635
# 81432                        1.001857
#
# [81433 rows x 69 columns]

# %%
sgRNA_breast_cancer = sgRNA_breast_cancer_DepMap[sgRNA_breast_cancer_DepMap['efficacy'].notnull()].loc[:,['guide_efficacy_sgRNA',
                                                                                                                            'guide_gene_map_gene',
                                                                                                                            'efficacy',
                                                                                                                            'MDAMB231-311Cas9_RepA_p5_batch2',
                                                                                                                            'MDAMB231-311Cas9_RepB_p5_batch2']]
sgRNA_breast_cancer = sgRNA_breast_cancer.drop_duplicates(['guide_efficacy_sgRNA'])
sgRNA_breast_cancer
# Out:
#        guide_efficacy_sgRNA guide_gene_map_gene  efficacy  \
# 0      TATTGGATACAAAGCAAAAG                 NaN  0.686422
# 69     GCTTTCACAGAATTATTCCA                 NaN  0.996387
# 113    GATCCTCTGAGAGTCCCAGG                 NaN  0.988974
# 151    GGCCATAGAATTCTCTCTGG     ZNF506 (440515)  0.797474
# 187    GTTTCTTTACTCAGCCCCTG     SPDYE3 (441272)  0.880902
# ...                     ...                 ...       ...
# 77492  TTTGTTGGAGAGATGTACGA       LIPH (200879)  0.999487
# 77493  TTTGTTGGCACAAATACGGG     RPL10L (140801)  0.999599
# 77494  TTTGTTGGCCACATCTACGG   C1orf137 (388667)  0.999890
# 77495  TTTGTTTCCTCTTCTCGAGG    CRISPLD1 (83690)  0.882474
# 77496  TTTGTTTGTCTCATTCATGG   C1orf210 (149466)  0.999691
#
#        MDAMB231-311Cas9_RepA_p5_batch2  MDAMB231-311Cas9_RepB_p5_batch2
# 0                            -3.225385                        -3.071423
# 69                           -3.721890                        -2.981994
# 113                          -2.572748                        -2.918988
# 151                          -3.100816                        -2.803211
# 187                          -2.627522                        -3.037610
# ...                                ...                              ...
# 77492                         0.017084                        -0.582310
# 77493                         0.147163                         0.192003
# 77494                        -0.130266                        -0.052341
# 77495                         0.725285                         0.723811
# 77496                         0.082488                         0.560648
#
# [69906 rows x 5 columns]

# %%
sgRNA_breast_cancer['guide_efficacy_sgRNA'] = [item + random.choice(['A', 'C', 'G', 'T']) + 'GG' for item in sgRNA_breast_cancer['guide_efficacy_sgRNA']]
sgRNA_breast_cancer
# Out:
#           guide_efficacy_sgRNA guide_gene_map_gene  efficacy  \
# 0      TATTGGATACAAAGCAAAAGAGG                 NaN  0.686422
# 69     GCTTTCACAGAATTATTCCAAGG                 NaN  0.996387
# 113    GATCCTCTGAGAGTCCCAGGCGG                 NaN  0.988974
# 151    GGCCATAGAATTCTCTCTGGTGG     ZNF506 (440515)  0.797474
# 187    GTTTCTTTACTCAGCCCCTGAGG     SPDYE3 (441272)  0.880902
# ...                        ...                 ...       ...
# 77492  TTTGTTGGAGAGATGTACGACGG       LIPH (200879)  0.999487
# 77493  TTTGTTGGCACAAATACGGGAGG     RPL10L (140801)  0.999599
# 77494  TTTGTTGGCCACATCTACGGTGG   C1orf137 (388667)  0.999890
# 77495  TTTGTTTCCTCTTCTCGAGGTGG    CRISPLD1 (83690)  0.882474
# 77496  TTTGTTTGTCTCATTCATGGGGG   C1orf210 (149466)  0.999691
#
#        MDAMB231-311Cas9_RepA_p5_batch2  MDAMB231-311Cas9_RepB_p5_batch2
# 0                            -3.225385                        -3.071423
# 69                           -3.721890                        -2.981994
# 113                          -2.572748                        -2.918988
# 151                          -3.100816                        -2.803211
# 187                          -2.627522                        -3.037610
# ...                                ...                              ...
# 77492                         0.017084                        -0.582310
# 77493                         0.147163                         0.192003
# 77494                        -0.130266                        -0.052341
# 77495                         0.725285                         0.723811
# 77496                         0.082488                         0.560648
#
# [69906 rows x 5 columns]

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_auc_score, average_precision_score
from scipy.stats import spearmanr

model = MultiHeadAttention_model(input_shape=(23, 4))
model.load_weights('/content/drive/MyDrive/Colab Notebooks/Cas9/On target/saved_model/Cas9_MultiHeadAttention_weights.keras')

x_test = np.concatenate(list(map(get_seqcode, sgRNA_breast_cancer['guide_efficacy_sgRNA'].to_list())))
pred_score = model.predict(x_test)
# Out:
# 2185/2185 [==============================] - 7s 3ms/step

# %%
# for efficacy

y_test = np.array(sgRNA_breast_cancer['efficacy']).reshape(-1,1,1,1)

# 60%
true_type = [1 if item > np.percentile(y_test, 60) else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 60) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 60% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 60% is {score}\n')

# 70%
true_type = [1 if item > np.percentile(y_test, 70) else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 70) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 70% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 70% is {score}\n')

# 80%
true_type = [1 if item > np.percentile(y_test, 80) else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 80) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 80% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 80% is {score}\n')

# 90%
true_type = [1 if item > np.percentile(y_test, 90) else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 90) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 90% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 90% is {score}\n')
# Out:
# Accuracy of active gRNA ranked top 60% is 0.5424
# ROC AUC of active gRNA ranked top 60% is 0.551
#
# Accuracy of active gRNA ranked top 70% is 0.5922
# ROC AUC of active gRNA ranked top 70% is 0.55
#
# Accuracy of active gRNA ranked top 80% is 0.689
# ROC AUC of active gRNA ranked top 80% is 0.5557
#
# Accuracy of active gRNA ranked top 90% is 0.8224
# ROC AUC of active gRNA ranked top 90% is 0.5508

# %%
# for log2FC MDA-MB-231 repA
y_test = np.array(abs(sgRNA_breast_cancer['MDAMB231-311Cas9_RepA_p5_batch2'])).reshape(-1,1,1,1)

# 60%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 60) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 60% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 60% is {score}\n')

# 70%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 70) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 70% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 70% is {score}\n')

# 80%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 80) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 80% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 80% is {score}\n')

# 90%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 90) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 90% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 90% is {score}\n')
# Out:
# Accuracy of active gRNA ranked top 60% is 0.5758
# ROC AUC of active gRNA ranked top 60% is 0.5151
#
# Accuracy of active gRNA ranked top 70% is 0.6429
# ROC AUC of active gRNA ranked top 70% is 0.5151
#
# Accuracy of active gRNA ranked top 80% is 0.7091
# ROC AUC of active gRNA ranked top 80% is 0.5151
#
# Accuracy of active gRNA ranked top 90% is 0.7744
# ROC AUC of active gRNA ranked top 90% is 0.5151

# %%
# for log2FC MDA-MB-231 repB
y_test = np.array(abs(sgRNA_breast_cancer['MDAMB231-311Cas9_RepB_p5_batch2'])).reshape(-1,1,1,1)

# 60%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 60) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 60% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 60% is {score}\n')

# 70%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 70) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 70% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 70% is {score}\n')

# 80%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 80) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 80% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 80% is {score}\n')

# 90%
true_type = [1 if item >= 1 else 0 for item in y_test]
pre_type = [1 if item > np.percentile(pred_score, 90) else 0 for item in pred_score]

score = np.round(accuracy_score(true_type, pre_type), 4)
print(f'Accuracy of active gRNA ranked top 90% is {score}')
score = np.round(roc_auc_score(true_type, pred_score.flatten()), 4)
print(f'ROC AUC of active gRNA ranked top 90% is {score}\n')
# Out:
# Accuracy of active gRNA ranked top 60% is 0.5723
# ROC AUC of active gRNA ranked top 60% is 0.5108
#
# Accuracy of active gRNA ranked top 70% is 0.6394
# ROC AUC of active gRNA ranked top 70% is 0.5108
#
# Accuracy of active gRNA ranked top 80% is 0.706
# ROC AUC of active gRNA ranked top 80% is 0.5108
#
# Accuracy of active gRNA ranked top 90% is 0.77
# ROC AUC of active gRNA ranked top 90% is 0.5108
